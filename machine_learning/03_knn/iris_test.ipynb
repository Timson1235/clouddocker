# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets, tree, metrics
import matplotlib.pyplot as plt
from classification_viz import plot_decisions_2d
from sklearn import datasets

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
# Download dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df = pd.read_csv(url, header=None, names=["sepal_length", "sepal_width", "petal_length", "petal_width", "class"])
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
X_1 = df.iloc[:,[2,3]].to_numpy()
y_1 = df.iloc[:,4].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X[:,[2,3]], y, test_size=0.4, shuffle=True, stratify=y, random_state=1)

# %%
X_1_train, X_1_test, y_1_train, y_1_test = train_test_split(X_1, y_1, test_size=0.4, shuffle=True, stratify=y, random_state=1)

# %%
from sklearn.preprocessing import LabelEncoder

# Assume y_1_train is a list or numpy array of categorical values
label_encoder = LabelEncoder()
y_1_train = label_encoder.fit_transform(y_1_train)

# %%
y_1_train
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 1, 0, 1, 0, 1, 2, 0, 2, 2, 2, 1, 0,
#        1, 1, 2, 1, 1, 0, 2, 2, 0, 1, 2, 1, 0, 2, 1, 1, 1, 1, 0, 0, 0, 1,
#        0, 0, 1, 2, 0, 0, 0, 1, 2, 2, 2, 1, 1, 1, 0, 2, 1, 2, 2, 1, 1, 2,
#        0, 0, 2, 1, 2, 0, 1, 2, 0, 0, 0, 1, 2, 1, 0, 1, 0, 0, 1, 0, 1, 0,
#        0, 0])

# %%
# Lets start with an arbitrary choice of parameters
from sklearn import neighbors
clf1 = neighbors.KNeighborsClassifier(3, 
    weights='uniform', 
    metric="euclidean", algorithm="brute")

# Train the classifier
clf1.fit(X_1_train, y_1_train)
# Out:
# KNeighborsClassifier(algorithm='brute', metric='euclidean', n_neighbors=3)

# %%
from classification_viz import plot_decisions_2d

# %%
plot_decisions_2d(X_train, y_train, clf1)
