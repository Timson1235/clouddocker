# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv("wdi.csv")
df20 = df.query("year==2020").reset_index(drop=True)
germany = df.query("country=='Germany'").reset_index(drop=True)

# %%
fig1 = px.scatter(df, x='year', y='greenhousegas_capita', color='country', size= 'population')
fig1.show()

# %%
fig2 = px.line(df, x = 'year', y = 'fertility', color= 'continent')
fig2.show()

# %%
china = df[df['country'] == 'China' ]
germany = df[df['country'] == 'Germany' ]

px.bar(china, x = 'gdp', y = 'greenhousegas_capita')
px.bar(germany, x = 'gdp', y = 'greenhousegas_capita', color_discrete_sequence=['#2f77b4'])
